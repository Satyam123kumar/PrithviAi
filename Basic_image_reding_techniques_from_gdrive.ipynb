# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# !unzip '/content/gdrive/My Drive/Data_set/train.zip' -d '/content/gdrive/My Drive/Data_set/'
# Out:
# Archive:  /content/gdrive/My Drive/Data_set/train.zip
# replace /content/gdrive/My Drive/Data_set/train/images/000012.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000012.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000016.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000019.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000023.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000032.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000039.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000045.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000059.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000068.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000073.png
#  extracting: /content/gdrive/My Drive/Data_set/train/images/000075.png
# ...

# %%
import matplotlib.pyplot as plt
import cv2
import os
from pathlib import Path

# %%
i = 4
fig = plt.figure(figsize=(10, 7))
rows = 2
columns = 2
for path in glob.glob("/content/gdrive/My Drive/Data_set/train/images/*"):
    if (i>0):
        img = cv2.imread(path)
        fig.add_subplot(rows, columns, i)
        plt.imshow(img)
        p = path.split("/")[-1]
        plt.title(p)
        i = i-1;

# %%
image = []
index = []

i = 500
for path in glob.glob("/content/gdrive/My Drive/Data_set/train/images/*"): 
  if (i>0):        # check if image exists or not
    img = cv2.imread(path, cv2.IMREAD_COLOR)       # read image using opencv 
    img = cv2.resize(img, (224,224))                                                                   #resize image 
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    image.append(img)
    p = path.split("/")[-1]
    index.append(p)
    i = i-1

# %%
index[:5]
# Out:
# ['000315.png', '000178.png', '000012.png', '000116.png', '000317.png']

# %%
path = pd.read_csv("/content/gdrive/My Drive/Data_set/train/labels/000012.txt", sep="\t")
(int)(path.columns[0].split(" ")[0])
# Out:
# 0

# %%
def fun(index, val):
  for i in index:
    if (i == val):
      return True

# %%
target = []
i=0
for path in glob.glob("/content/gdrive/My Drive/Data_set/train/labels/*"):
  p = path.split("/")[-1] 
  # print(p)
  p1 = p.split(".")[0] + ".png"
  # print(p1)
  # print(index)

  if (fun(index, p1)):
    # print(p1)
    path = pd.read_csv("/content/gdrive/My Drive/Data_set/train/labels/"+p, sep="\t")
    
    t = int(path.columns[0].split(" ")[0])
    # print(t)
    target.append(t)

# %%
path = pd.read_csv("/content/gdrive/My Drive/Data_set/train/labels/"+"000012.txt", sep="\t")
int(path.columns[0].split(" ")[0])
# Out:
# 0

# %%
len(image)
# Out:
# 500

# %%
targets = np.array(target)

# %%
targets.sum()
# Out:
# 0
